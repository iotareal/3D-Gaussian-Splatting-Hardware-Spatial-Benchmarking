# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

sns.set_theme(style="whitegrid", context="paper", font_scale=1.2)
logs = Path(Path.cwd().parent) / "assets" / "GPU-logs-csv"

ballroom_rtx3060_2 = pd.read_csv(logs / "temple_rtx3060_12G_8.csv")
columns = list(ballroom_rtx3060_2.columns)
print(f"time: {ballroom_rtx3060_2[columns[0]].max()}")
print(f"memory: {ballroom_rtx3060_2[columns[1]].max()}")
print(f"GPU util: {ballroom_rtx3060_2[columns[2]].max()}")
print(f"pwr: {ballroom_rtx3060_2[columns[3]].max()}")
# Out:
# time: 10.4494
# memory: 1418
# GPU util: 98
# pwr: 121.23

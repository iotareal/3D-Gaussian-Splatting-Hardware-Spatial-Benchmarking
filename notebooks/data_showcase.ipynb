# %%
import pandas as pd
from IPython.display import display
from pathlib import Path

baseDir = Path.cwd().parent / "custom-pipeline" / "Benchmarking" / "GPU_Logs"
df = pd.read_csv(str(baseDir / "locomotive_rtx3060_12G_1.csv")).sort_values(by="Time_Minutes")
display(df)
# df = pd.read_csv("custom-pipeline/Benchmarking/GPU_logs/results_locomotive_rtx3060_12G_2.csv").sort_values(by="Iterations")
# display(df)
# df = pd.read_csv("custom-pipeline/Benchmarking/GPU_logs/results_locomotive_rtx3060_12G_4.csv").sort_values(by="Iterations")
# display(df)
# df = pd.read_csv("custom-pipeline/Benchmarking/GPU_logs/results_locomotive_rtx3060_12G_8.csv").sort_values(by="Iterations")
# display(df)
# df = pd.read_csv("custom-pipeline/Benchmarking/GPU_logs/results_tank_rtx3060_12G_4.csv").sort_values(by="Iterations")
# display(df)
# df = pd.read_csv("custom-pipeline/Benchmarking/GPU_logs/results_tank_rtx3060_12G_8.csv").sort_values(by="Iterations")
# display(df)
# Out:
#       Time_Minutes  Memory_Used_MiB  GPU_Utilization_Pct  Power_Watts
# 0           0.0000              944                    0         8.05
# 1           0.0173              953                    0         8.48
# 2           0.0348              956                    0         8.89
# 3           0.0522              956                    0         8.40
# 4           0.0695             1458                    6        22.53
# ...            ...              ...                  ...          ...
# 2126       37.0849             6431                   99       149.82
# 2127       37.1024             6431                   99       149.16
# 2128       37.1199             6431                   99       149.15
# 2129       37.1375             6431                    0       110.61
# 2130       37.1549             6442                    2        53.63
#
# [2131 rows x 4 columns]
